# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as py

# %%
#reading csv file and get currency name accroding to this create new csv sheet with all the details of that currency
df = pd.read_csv('all_crypto_list.csv', sep=',')
df.head()
# Out:
#              id          name symbol  rank    price_usd  price_btc  \
# 0       bitcoin       Bitcoin    BTC     1  8248.660000   1.000000
# 1      ethereum      Ethereum    ETH     2   458.963000   0.055722
# 2  bitcoin-cash  Bitcoin Cash    BCH     3  1715.230000   0.208243
# 3        ripple        Ripple    XRP     4     0.242877   0.000029
# 4          dash          Dash   DASH     5   565.962000   0.068712
#
#    24h_volume_usd  market_cap_usd  available_supply  total_supply  \
# 0    5.066580e+09    1.377448e+11      1.669905e+07  1.669905e+07
# 1    2.117850e+09    4.402765e+10      9.592854e+07  9.592854e+07
# 2    3.400890e+09    2.885038e+10      1.682012e+07  1.682012e+07
# 3    2.337860e+08    9.380607e+09      3.862287e+10  9.999317e+10
# 4    1.373310e+08    4.362462e+09      7.708047e+06  7.708047e+06
#
#      max_supply  percent_change_1h  percent_change_24h  percent_change_7d  \
# 0  2.100000e+07               0.51                0.99               5.37
# ...
